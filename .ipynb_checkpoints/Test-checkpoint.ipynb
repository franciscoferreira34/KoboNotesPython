# %%
from main import getBooks,BookToTXT,loadDatabase,createUnifiedDatabase,saveBooksToTXT

# %%
books = getBooks("../KoboNotesSQLiteFiles/KoboReader.sqlite")
# Out:
# 10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works--A True Story
# An Astronaut's Guide to Life on Earth
# Elon Musk
# Flow
# Fooled by Randomness
# Guns, Germs, and Steel
# How To Be Idle
# Learned Optimism
# Making a Living Without a Job: Winning Ways for Creating Work That You Love
# Man's Search for Meaning
# On Writing Well
# Outliers: The Story of Success
# Philosophy for Life and Other Dangerous Situations
# Quiet: The Power of Introverts in a World That Can't Stop Talking
# Sapiens: A Brief History of Humankind
# The $100 Startup: Reinvent the Way You Make a Living, Do What You Love, and Create a New Future
# The 36-Hour Day
# The 4-Hour Body: An Uncommon Guide to Rapid Fat-Loss, Incredible Sex, and Becoming Superhuman
# The 4-Hour Workweek
# The Four Agreements
# The Game
# The Happiness Hypothesis
# The Know-it-All: One Man's Humble Quest to Become the Smartest Person in the World
# ...

# %%
BookToTXT("../KoboNotesSQLiteFiles/KoboReader.sqlite",'Fooled by')
# Out:
# Book not available. Try one of the following books:
#
# 10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works--A True Story
# An Astronaut's Guide to Life on Earth
# Elon Musk
# Flow
# Fooled by Randomness
# Guns, Germs, and Steel
# How To Be Idle
# Learned Optimism
# Making a Living Without a Job: Winning Ways for Creating Work That You Love
# Man's Search for Meaning
# On Writing Well
# Outliers: The Story of Success
# Philosophy for Life and Other Dangerous Situations
# Quiet: The Power of Introverts in a World That Can't Stop Talking
# Sapiens: A Brief History of Humankind
# The $100 Startup: Reinvent the Way You Make a Living, Do What You Love, and Create a New Future
# The 36-Hour Day
# The 4-Hour Body: An Uncommon Guide to Rapid Fat-Loss, Incredible Sex, and Becoming Superhuman
# The 4-Hour Workweek
# The Four Agreements
# The Game
# The Happiness Hypothesis
# ...

# %%
BookToTXT("../KoboNotesSQLiteFiles/KoboReader.sqlite",'The Monk Who Sold His Ferrari')

# %%
bookmark,content = loadDatabase("../KoboNotesSQLiteFiles/KoboReader.sqlite")
    
data = createUnifiedDatabase(bookmark,content)

# %%
data[data.Title=='The Monk Who Sold His Ferrari']
# Out:
#                                              VolumeID  \
# 14  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 28  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 13  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 23  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 27  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 11  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 0   file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 4   file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 2   file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 18  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 22  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 7   file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 20  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 5   file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 8   file:///mnt/onboard/Sharma, Robin/The Monk Who...
# 12  file:///mnt/onboard/Sharma, Robin/The Monk Who...
# ...

# %%
saveBooksToTXT("../KoboNotesSQLiteFiles/KoboReader.sqlite","/home/francisco/Desktop")

# %%
import os

# %%
os.path.join("dsds","dsds")
# Out:
# 'dsds/dsds'

# %%
from docx import Document
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-6d471520889f> in <module>()
# ----> 1 from docx import Document
#
# ImportError: No module named 'docx'

# %%
import docx

# %%
from docx import Document
from docx.shared import Inches

document = Document()

document.add_heading('Document Title', 2)

p = document.add_paragraph('A plain paragraph having some ')
p = document.add_paragraph('A plain pdsdsaragraph having some ')

p.add_run('bold').bold = True
p.add_run(' and some ')
p.add_run('italic.').italic = True

document.add_heading('Heading, level 1', level=1)
document.add_paragraph('Intense quote', style='IntenseQuote')

document.add_paragraph(
    'first item in unordered list', style='ListBullet'
)
document.add_paragraph(
    'first item in ordered list', style='ListNumber'
)


table = document.add_table(rows=1, cols=3)
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'

document.add_page_break()

document.save('demo.docx')
# Out:
# /home/francisco/.virtualenvs/virtual-py3/lib/python3.5/site-packages/docx/styles/styles.py:54: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   warn(msg, UserWarning)
